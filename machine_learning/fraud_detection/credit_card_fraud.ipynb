# %%
# YouTube Eduonix - https://www.youtube.com/watch?v=gCWBFyFTxVU&t=2144s

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe().transpose()
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  3.919560e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  5.688174e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -8.769071e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.782312e-15      1.415869   -5.683171     -0.848640
# V5      284807.0 -1.552563e-15      1.380247 -113.743307     -0.691597
# V6      284807.0  2.010663e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -1.694249e-15      1.237094  -43.557242     -0.554076
# V8      284807.0 -1.927028e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -3.137024e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  1.768627e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  9.170318e-16      1.020713   -4.797473     -0.762494
# ...

# %%
# if you want to sample, you can type df = df.sample(frac = 0.1, random_state= 1)
# there are 492 frauds in this dataset
df['Class'].value_counts(normalize=True)
# Out:
# 0    0.998273
# 1    0.001727
# Name: Class, dtype: float64

# %%
df.hist(figsize = (20,20))
plt.show()

# %%
fraud = df[df['Class'] == 1]
valid = df[df['Class'] == 0]

outlier_fraction = len(fraud) / float(len(valid))

print('Percentage of fraud {}'.format(outlier_fraction))
print('Fraud cases: {}'.format(len(fraud)))
print('Valid cases: {}'.format(len(valid)))
# Out:
# Percentage of fraud 0.0017304750013189597
# Fraud cases: 492
# Valid cases: 284315

# %%
corrmat = df.corr()
fig = plt.figure(figsize=(12, 9))

sns.heatmap(corrmat, vmax = .8)

# %%
# get all the columns from the dataframe
columns = df.columns.tolist()

# filter the columsn to remove data we do not want
columns = [c for c in columns if c not in ['Class']]

target = 'Class'

x = df[columns]
y = df[target]

print(x.shape)
print(y.shape)
# Out:
# (284807, 30)
# (284807,)

# %%
# import packages for anomaly detection

from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor

# localoutlierfactor is unsupervised outlier detection method. calculates anomaly score of each sample. measures the local
#   deviation of density of a givien sample with respect to its neighbors. it is local in that anmaly score depends on how
#   isolated the object is with respect to the surrounding neighborhood. neighbors like KNN, except this is calculating an
#   anomaly score

# isolationforest returns the anomaly score of each sample using this isolation forest method so it does that and it
#   isolates the obervation by randomly selecting a feature and then randomly selecting a split value between the maximum 
#   and minimum values of the selected feature.

# %%
# define a random state
state = 1

classifiers = {
    'Isolation Forest' : IsolationForest(max_samples=len(x),
                                        contamination = outlier_fraction,
                                        random_state = state),
    'Local Outlier Factor' : LocalOutlierFactor(n_neighbors = 20,
                                               contamination = outlier_fraction)
}

# %%
# fit the model
n_outliers = len(fraud)

for i, (clf_name, clf) in enumerate(classifiers.items()):
    
    # fit the data and tag outliers
    if clf_name == 'Local Outlier Factor':
        y_pred = clf.fit_predict(x)
        scores_pred = clf.negative_outlier_factor_
    else:
        clf.fit(x)
        scores_pred = clf.decision_function(x)
        y_pred = clf.predict(x)
        
    
   # reshape the rediction values to - for valid, 1 for fraud
    y_pred[y_pred == 1] = 0
    y_pred[y_pred == -1] = 1
    
    n_errors = (y_pred != y).sum()
    
    # run classification metrics
    print('{}: {}'.format(clf_name, n_errors))
    print(accuracy_score(y, y_pred))
    print(classification_report(y, y_pred))
# Out:
# Isolation Forest: 645
# 0.997735308472053
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00    284315
#           1       0.34      0.35      0.35       492
#
# avg / total       1.00      1.00      1.00    284807
#
# Local Outlier Factor: 935
# 0.9967170750718908
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00    284315
#           1       0.05      0.05      0.05       492
#
# avg / total       1.00      1.00      1.00    284807
