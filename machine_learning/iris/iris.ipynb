# %%
from sklearn import datasets

# %%
from sklearn import (decomposition,
                    metrics,
                    model_selection as skms,
                    pipeline,
                    preprocessing as skpre,
                    neighbors,
                    linear_model)

# %%
iris = datasets.load_iris()

# %%
# target is what we want to predict (our 'y')
iris.target[:3] #0000, 11111, 22222
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
# our imputs ... independent variables
iris.data[:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
import pandas as pd
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['tgt'] = iris.target_names[iris.target]

# %%
import seaborn as sns
# %matplotlib inline
sns.pairplot(iris_df, hue='tgt')

# %%
iris = datasets.load_iris()
dir(iris)
# Out:
# ['DESCR', 'data', 'feature_names', 'target', 'target_names']

# %%
# we have our X-y division from feature and target
(iris_train_ftrs, iris_test_ftrs, iris_train_tgt, iris_test_tgt) = skms.train_test_split(iris.data, iris.target, test_size=.25)

# %%
knn = neighbors.KNeighborsClassifier()
fit_knn = knn.fit(iris_train_ftrs, iris_train_tgt)

preds = fit_knn.predict(iris_test_ftrs)
preds[:5]
# Out:
# array([0, 1, 2, 2, 2])

# %%
metrics.accuracy_score(iris_test_tgt, preds)
# Out:
# 1.0

# %%
preds = (neighbors.KNeighborsClassifier()
                  .fit(iris_train_ftrs, iris_train_tgt)
                  .predict(iris_test_ftrs))

preds[:5]
# Out:
# array([0, 1, 2, 2, 2])

# %%
diabetes = datasets.load_diabetes()

(diab_train_ftrs, diab_test_ftrs, diab_train_tgt, diab_test_tgt) = skms.train_test_split(diabetes.data,
                                                                                        diabetes.target,
                                                                                        test_size=.25)

preds = (linear_model.LinearRegression()
                     .fit(diab_train_ftrs, diab_train_tgt)
                     .predict(diab_test_ftrs))


print(preds[:5])
metrics.mean_squared_error(diab_test_tgt, preds)
# Out:
# [145.2818052  244.41506931  75.82639704 164.36226164  59.10672777]
# 3004.849760507626
